# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # reading images

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt

# Load the YOLOv8 model
model = YOLO('yolo11n.pt')  
# Load an image for detection
image_path = 'buddy.jpg'  # Update with your test image path
img = cv2.imread(image_path)

# Run inference on the image
results = model.predict(source=img, save=False, conf=0.5)


# Visualize results
# Process results
for result in results:
    if result.boxes:  # Check if there are any detections
        for box in result.boxes:
            # Extract box details
            xyxy = box.xyxy.cpu().numpy()[0] if hasattr(box, 'xyxy') else None
            conf = box.conf.cpu().numpy()[0] if hasattr(box, 'conf') else None
            cls_id = int(box.cls.cpu().numpy()[0]) if hasattr(box, 'cls') else None
            
            if xyxy is not None and conf is not None and cls_id is not None:
                x1, y1, x2, y2 = xyxy
                class_name = model.names[cls_id]
                
                # Draw bounding boxes and labels
                cv2.rectangle(img, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)
                label = f"{class_name}: {conf:.2f}"
                cv2.putText(img, label, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
            else:
                print("Incomplete box attributes.")
    else:
        print("No detections found.")


# Display the image
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# Optional: Save the output image
cv2.imwrite('output.png', img)
# Out:
# 0: 576x640 1 bird, 335.5ms
# Speed: 8.2ms preprocess, 335.5ms inference, 18.5ms postprocess per image at shape (1, 3, 576, 640)
# True

# %%
# Load the image
image_path = "cat1.jpg"  # Replace with your image path
img = cv2.imread(image_path)

# Run inference
results = model.predict(img, conf=0.25)

# Process results
for result in results:
    if result.boxes:  # Check if there are any detections
        for box in result.boxes:
            # Extract box details
            xyxy = box.xyxy.cpu().numpy().flatten()  # Bounding box coordinates (x1, y1, x2, y2)
            x1, y1, x2, y2 = map(int, xyxy)
            conf = box.conf.cpu().numpy().item()  # Confidence score
            cls_id = int(box.cls.cpu().numpy().item())  # Class ID
            class_name = model.names[cls_id]  # Get class name
            
            # Draw bounding box
            cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
            
            # Add label with confidence
            label = f"{class_name}: {conf:.2f}"
            cv2.putText(img, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    else:
        print("No detections found.")

# Convert BGR to RGB for display in Matplotlib
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Display the image
plt.imshow(img_rgb)
plt.axis('off')
plt.show()

# Optional: Save the output image
cv2.imwrite("output1.jpg", img)
# Out:
# 0: 448x640 2 cats, 193.9ms
# Speed: 9.8ms preprocess, 193.9ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# True

# %%
# Load the image
image_path = "car.jpg"  # Replace with your image path
img = cv2.imread(image_path)

# Run inference
results = model.predict(img, conf=0.25)

# Process results
for result in results:
    if result.boxes:  # Check if there are any detections
        for box in result.boxes:
            # Extract box details
            xyxy = box.xyxy.cpu().numpy().flatten()  # Bounding box coordinates (x1, y1, x2, y2)
            x1, y1, x2, y2 = map(int, xyxy)
            conf = box.conf.cpu().numpy().item()  # Confidence score
            cls_id = int(box.cls.cpu().numpy().item())  # Class ID
            class_name = model.names[cls_id]  # Get class name
            
            # Draw bounding box
            cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
            
            # Add label with confidence
            label = f"{class_name}: {conf:.2f}"
            cv2.putText(img, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    else:
        print("No detections found.")

# Convert BGR to RGB for display in Matplotlib
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Display the image
plt.imshow(img_rgb)
plt.axis('off')
plt.show()

# Optional: Save the output image
cv2.imwrite("output2.jpg", img)
# Out:
# 0: 640x640 1 car, 192.6ms
# Speed: 6.7ms preprocess, 192.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# True

# %%
# Load the image
image_path = "van.jpg"  # Replace with your image path
img = cv2.imread(image_path)

# Run inference
results = model.predict(img, conf=0.25)

# Process results
for result in results:
    if result.boxes:  # Check if there are any detections
        for box in result.boxes:
            # Extract box details
            xyxy = box.xyxy.cpu().numpy().flatten()  # Bounding box coordinates (x1, y1, x2, y2)
            x1, y1, x2, y2 = map(int, xyxy)
            conf = box.conf.cpu().numpy().item()  # Confidence score
            cls_id = int(box.cls.cpu().numpy().item())  # Class ID
            class_name = model.names[cls_id]  # Get class name
            
            # Draw bounding box
            cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
            
            # Add label with confidence
            label = f"{class_name}: {conf:.2f}"
            cv2.putText(img, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    else:
        print("No detections found.")

# Convert BGR to RGB for display in Matplotlib
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Display the image
plt.imshow(img_rgb)
plt.axis('off')
plt.show()

# Optional: Save the output image
cv2.imwrite("output3.jpg", img)
# Out:
# 0: 448x640 1 bus, 137.6ms
# Speed: 5.1ms preprocess, 137.6ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# True

# %%
# Load the image
image_path = "person.jpg"  # Replace with your image path
img = cv2.imread(image_path)

# Run inference
results = model.predict(img, conf=0.25)

# Process results
for result in results:
    if result.boxes:  # Check if there are any detections
        for box in result.boxes:
            # Extract box details
            xyxy = box.xyxy.cpu().numpy().flatten()  # Bounding box coordinates (x1, y1, x2, y2)
            x1, y1, x2, y2 = map(int, xyxy)
            conf = box.conf.cpu().numpy().item()  # Confidence score
            cls_id = int(box.cls.cpu().numpy().item())  # Class ID
            class_name = model.names[cls_id]  # Get class name
            
            # Draw bounding box
            cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
            
            # Add label with confidence
            label = f"{class_name}: {conf:.2f}"
            cv2.putText(img, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    else:
        print("No detections found.")

# Convert BGR to RGB for display in Matplotlib
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Display the image
plt.imshow(img_rgb)
plt.axis('off')
plt.show()

# Optional: Save the output image
cv2.imwrite("output4.jpg", img)
# Out:
# 0: 448x640 1 person, 1 bench, 107.1ms
# Speed: 3.8ms preprocess, 107.1ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
# True

# %%
# Load the image
image_path = "dog.jpg"  # Replace with your image path
img = cv2.imread(image_path)

# Run inference
results = model.predict(img, conf=0.25)

# Process results
for result in results:
    if result.boxes:  # Check if there are any detections
        for box in result.boxes:
            # Extract box details
            xyxy = box.xyxy.cpu().numpy().flatten()  # Bounding box coordinates (x1, y1, x2, y2)
            x1, y1, x2, y2 = map(int, xyxy)
            conf = box.conf.cpu().numpy().item()  # Confidence score
            cls_id = int(box.cls.cpu().numpy().item())  # Class ID
            class_name = model.names[cls_id]  # Get class name
            
            # Draw bounding box
            cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
            
            # Add label with confidence
            label = f"{class_name}: {conf:.2f}"
            cv2.putText(img, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    else:
        print("No detections found.")

# Convert BGR to RGB for display in Matplotlib
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Display the image
plt.imshow(img_rgb)
plt.axis('off')
plt.show()

# Optional: Save the output image
cv2.imwrite("output5.jpg", img)
# Out:
# 0: 480x640 2 dogs, 249.9ms
# Speed: 7.4ms preprocess, 249.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# True

# %%
# Load the image
image_path = "room.jpg"  # Replace with your image path
img = cv2.imread(image_path)

# Run inference
results = model.predict(img, conf=0.25)

# Process results
for result in results:
    if result.boxes:  # Check if there are any detections
        for box in result.boxes:
            # Extract box details
            xyxy = box.xyxy.cpu().numpy().flatten()  # Bounding box coordinates (x1, y1, x2, y2)
            x1, y1, x2, y2 = map(int, xyxy)
            conf = box.conf.cpu().numpy().item()  # Confidence score
            cls_id = int(box.cls.cpu().numpy().item())  # Class ID
            class_name = model.names[cls_id]  # Get class name
            
            # Draw bounding box
            cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
            
            # Add label with confidence
            label = f"{class_name}: {conf:.2f}"
            cv2.putText(img, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    else:
        print("No detections found.")

# Convert BGR to RGB for display in Matplotlib
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Display the image
plt.imshow(img_rgb)
plt.axis('off')
plt.show()

# Optional: Save the output image
cv2.imwrite("output6.jpg", img)
# Out:
# 0: 384x640 1 horse, 1 bed, 2 tvs, 1 laptop, 146.6ms
# Speed: 7.9ms preprocess, 146.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# True

# %%
# Load the image
image_path = "room1.jpg"  # Replace with your image path
img = cv2.imread(image_path)

# Run inference
results = model.predict(img, conf=0.25)

# Process results
for result in results:
    if result.boxes:  # Check if there are any detections
        for box in result.boxes:
            # Extract box details
            xyxy = box.xyxy.cpu().numpy().flatten()  # Bounding box coordinates (x1, y1, x2, y2)
            x1, y1, x2, y2 = map(int, xyxy)
            conf = box.conf.cpu().numpy().item()  # Confidence score
            cls_id = int(box.cls.cpu().numpy().item())  # Class ID
            class_name = model.names[cls_id]  # Get class name
            
            # Draw bounding box
            cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
            
            # Add label with confidence
            label = f"{class_name}: {conf:.2f}"
            cv2.putText(img, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    else:
        print("No detections found.")

# Convert BGR to RGB for display in Matplotlib
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Display the image
plt.imshow(img_rgb)
plt.axis('off')
plt.show()

# Optional: Save the output image
cv2.imwrite("output7.jpg", img)
# Out:
# 0: 576x640 1 chair, 4 potted plants, 1 tv, 2 books, 3 vases, 302.2ms
# Speed: 52.9ms preprocess, 302.2ms inference, 29.5ms postprocess per image at shape (1, 3, 576, 640)
# True

# %% [markdown]
# # READING VEDIO

# %%
import cv2
from ultralytics import YOLO
import logging

logging.getLogger("ultralytics").setLevel(logging.ERROR)

# Load the YOLOv8 model
model = YOLO("yolo11n.pt")  # Replace with your model file

# Video input (replace 'video.mp4' with the path to your video file)
video_path = "street.mp4"
cap = cv2.VideoCapture(video_path)

# Define colors for bounding boxes (predefined or randomized)
class_colors = [
    (0, 255, 0),  # Green
    (0, 255, 255),  # Yellow
    (255, 0, 0),  # Blue
    (0, 0, 255),  # Red
    (255, 165, 0),  # Orange
    (128, 0, 128),  # Purple
]

if not cap.isOpened():
    print(f"Failed to open the video file: {video_path}")
else:
    while True:
        ret, frame = cap.read()
        if not ret:
            print("End of video or cannot read the frame.")
            break

        # Run YOLOv8 inference
        results = model.predict(frame, conf=0.25)

        for result in results:
            if result.boxes:  # Check if there are any detections
                for box in result.boxes:
                    # Extract box details
                    xyxy = box.xyxy.cpu().numpy().flatten()  # Bounding box coordinates (x1, y1, x2, y2)
                    x1, y1, x2, y2 = map(int, xyxy)
                    conf = box.conf.cpu().numpy().item()  # Confidence score
                    cls_id = int(box.cls.cpu().numpy().item())  # Class ID
                    class_name = model.names[cls_id]  # Get class name

                    # Choose a color for the bounding box
                    color = class_colors[cls_id % len(class_colors)]

                    # Draw bounding box
                    cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)

                    # Add label with confidence
                    label = f"{class_name}: {conf:.2f}"
                    cv2.putText(frame, label, (x1, max(0, y1 - 10)), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

        # Display the frame
        cv2.imshow("Object Detection", frame)

        # Press 'q' to quit
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# End of video or cannot read the frame.

# %% [markdown]
# # reading vedio with logs and saving output vedio

# %%
import cv2
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO("yolo11n.pt")  # Replace with your model file

# Video input (replace 'video.mp4' with the path to your video file)
video_path = "street.mp4"
cap = cv2.VideoCapture(video_path)

# Get video properties
fps = cap.get(cv2.CAP_PROP_FPS)  # Frames per second
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))  # Frame width
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))  # Frame height

# Define the codec and create VideoWriter object
output_path = "output_video.mp4"
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for .mp4 format
out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

# Check if the video file is opened successfully
if not cap.isOpened():
    print(f"Failed to open the video file: {video_path}")
    exit()

while True:
    ret, frame = cap.read()
    if not ret:
        print("End of video reached.")
        break

    # Run YOLOv8 inference
    results = model.predict(frame, conf=0.25)

    for result in results:
        if result.boxes:  # Check if there are any detections
            for box in result.boxes:
                # Extract box details
                xyxy = box.xyxy.cpu().numpy().flatten()  # Bounding box coordinates (x1, y1, x2, y2)
                x1, y1, x2, y2 = map(int, xyxy)
                conf = box.conf.cpu().numpy().item()  # Confidence score
                cls_id = int(box.cls.cpu().numpy().item())  # Class ID
                class_name = model.names[cls_id]  # Get class name

                # Draw bounding box
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)

                # Add label with confidence
                label = f"{class_name}: {conf:.2f}"
                cv2.putText(frame, label, (x1, max(0, y1 - 10)), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Write the processed frame to the output video
    out.write(frame)

    # Display the frame (optional)
    cv2.imshow("Object Detection", frame)

    # Press 'q' to quit early
    if cv2.waitKey(1) & 0xFF == ord('q'):
        print("Video playback interrupted by user.")
        break

# Release resources
cap.release()
out.release()  # Save the video file
cv2.destroyAllWindows()
print(f"Output video saved as: {output_path}")
# Out:
# 0: 384x640 (no detections), 304.1ms
# Speed: 8.3ms preprocess, 304.1ms inference, 11.5ms postprocess per image at shape (1, 3, 384, 640)
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# 0: 384x640 2 persons, 4 cars, 1 bus, 107.0ms
# Speed: 3.6ms preprocess, 107.0ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 5 cars, 1 bus, 94.7ms
# Speed: 1.7ms preprocess, 94.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 5 cars, 1 bus, 100.1ms
# Speed: 1.6ms preprocess, 100.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 6 cars, 1 bus, 95.8ms
# Speed: 4.2ms preprocess, 95.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 7 cars, 1 bus, 1 truck, 90.5ms
# Speed: 1.6ms preprocess, 90.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
